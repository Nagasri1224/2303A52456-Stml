# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagasri1224/2303A52456-Stml/blob/main/Stml%20lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Given the following dataset: X={2.3,2.5,3.6,2.8,3.1,2.9,3.2,2.7,2.8,3.0}. Compute the density of the data using a histogram with 5 bins.

# %%
import matplotlib.pyplot as plt
import numpy as np
X=[2.3,2.5,3.6,2.8,3.1,2.9,3.2,2.7,2.8,3.0]
plt.hist(X,bins=5,density=True,edgecolor='brown')
plt.title('Histogram of X')
plt.xlabel('X')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# Question 2:
#
# (dependent variables)
# 4 5 8 2 4 2 5
#
# (independent variables) 5 6 3 8 3 7 8
#
# Find Mean, Median, Mode , Variance , Standard deviation , Range , Interquartile Range (IQR), Skewness ,Kurtosis of x and y .

# %%
import numpy as np
from scipy.stats import kurtosis
dv=[4,5,8,2,4,2,5]
iv=[5,6,3,8,3,7,8]
dv1=np.array(dv)
iv1=np.array(iv)
print("Mean of dv:",np.mean(dv1))
print("Mean of iv:",np.mean(iv1))
print("Median of dv:",np.median(dv1))
print("Median of iv:",np.median(iv1))
print("Mode of dv:",np.argmax(np.bincount(dv1)))
print("Mode of iv:",np.argmax(np.bincount(iv1)))
print("Variance of dv:",np.var(dv1))
print("Variance of iv:",np.var(iv1))
print("Standard deviation of dv:",np.std(dv1))
print("Standard deviation of iv:",np.std(iv1))
print("Range of dv:",np.max(dv1)-np.min(dv1))
print("Range of iv:",np.max(iv1)-np.min(iv1))
q1,q3=np.percentile(dv1,[25,75])
iqr=q3-q1
print("Interquartile range of dv:",iqr)
q1,q3=np.percentile(iv1,[25,75])
iqr=q3-q1
print("Interquartile range of iv:",iqr)
print("Skewness of dv:",np.mean((dv1-np.mean(dv1))/np.std(dv1)))
print("Skewness of iv:",np.mean((iv1-np.mean(iv1))/np.std(iv1)))
print("Kurtosis of dv:", kurtosis(dv1))
print("Kurtosis of iv:", kurtosis(iv1))
# Out:
# Mean of dv: 4.285714285714286
# Mean of iv: 5.714285714285714
# Median of dv: 4.0
# Median of iv: 6.0
# Mode of dv: 2
# Mode of iv: 3
# Variance of dv: 3.6326530612244894
# Variance of iv: 3.918367346938776
# Standard deviation of dv: 1.9059520091609048
# Standard deviation of iv: 1.979486637221574
# Range of dv: 6
# Range of iv: 5
# Interquartile range of dv: 2.0
# Interquartile range of iv: 3.5
# Skewness of dv: 7.137148015447435e-17
# Skewness of iv: -6.344131569286608e-17
# Kurtosis of dv: -0.34282287589950755
# Kurtosis of iv: -1.4541015625000002

# %% [markdown]
# Q3. From the above data Find Mean, Median, Mode, Variance, Standard deviation, Range , Interquartile Range (IQR), Skewness ,Kurtosis of each feature

# %%
import pandas as pd
import matplotlib.pyplot as plt
df1=pd.read_csv('/content/sample_data/california_housing_test.csv')
print(df1)
print(df1.describe())
plt.hist(df1['longitude'],bins=10,density=True,edgecolor='black')
plt.title('Histogram of longitude')
plt.xlabel('longitude')
plt.ylabel('Density')
plt.show()
print()
plt.hist(df1['latitude'],bins=10,density=True,edgecolor='black')
plt.title('Histogram of latitude')
plt.xlabel('latitude')
plt.ylabel('Density')
plt.show()
print()
plt.hist(df1['housing_median_age'],bins=10,density=True,edgecolor='black')
plt.title('Histogram of housing_median_age')
plt.xlabel('housing_median_age')
plt.ylabel('Density')
plt.show()
print()
plt.hist(df1['total_rooms'],bins=10,density=True,edgecolor='black')
plt.title('Histogram of total_rooms')
plt.xlabel('total_rooms')
plt.ylabel('Density')
plt.show()
print()
plt.hist(df1['total_bedrooms'],bins=10,density=True,edgecolor='black')
plt.title('Histogram of total_bedrooms')
plt.xlabel('total_bedrooms')
plt.ylabel('Density')
plt.show()
print()
plt.hist(df1['population'],bins=10,density=True,edgecolor='black')
plt.title('Histogram of population')
plt.xlabel('population')
plt.ylabel('Density')
plt.show()
print()
plt.hist(df1['households'],bins=10,density=True,edgecolor='black')
plt.title('Histogram of households')
plt.xlabel('households')
plt.ylabel('Density')
plt.show()
print()
plt.hist(df1['median_income'],bins=10,density=True,edgecolor='black')
plt.title('Histogram of median_income')
plt.xlabel('median_income')
plt.ylabel('Density')
plt.show()
print()
plt.hist(df1['median_house_value'],bins=10,density=True,edgecolor='black')
plt.title('Histogram of median_house_value')
plt.xlabel('median_house_value')
plt.ylabel('Density')
plt.show()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [3000 rows x 9 columns]
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# 25%        291.000000    780.000000   273.00000       2.544000
# 50%        437.000000   1155.000000   409.50000       3.487150
# 75%        636.000000   1742.750000   597.25000       4.656475
# max       5419.000000  11935.000000  4930.00000      15.000100
#
#        median_house_value
# count          3000.00000
# mean         205846.27500
# std          113119.68747
# min           22500.00000
# 25%          121200.00000
# 50%          177650.00000
# 75%          263975.00000
# max          500001.00000
